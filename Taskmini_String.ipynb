# %%
# Find the length of a given string without using the len() function

str = input("Enter a string: ")
print("You entered:", str)
length = 0
for char in str:
    length += 1
print("Length of the string is:", length)
# Out:
# You entered: Hellooo world
# Length of the string is: 13

# %%
# Extract username from a given email. 
# Eg if the email is nitish24singh@gmail.com 
# then the username should be nitish24singh

str = input("Enter an email: ")
print("You entered:", str)
username = ""
for char in str:
    if char == "@":
        break
    username = username + char
print("Username is:", username)
# Out:
# You entered: tanya21raikwar@gmail.com
# Username is: tanya21raikwar

# %%
# Count the frequency of a particular character in a provided string. 
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.

str = input("Enter a string: ")
print("You entered:", str)
char = input("Enter a character: ") 
count = 0
for c in str:
    if c == char:
        count += 1
print("Frequency of", char, "is:", count)
# Out:
# You entered: Tanya raikwar
# Frequency of a is: 4

# %%
# Write a program which can remove a particular character from a string.

str = input("Enter a string: ")
print("You entered:", str)
char = input("Enter a character to remove: ")
new_str = ""
for c in str:
    if c != char:
        new_str = new_str + c
print("String after removing", char, "is:", new_str)
# Out:
# You entered: tanya raikwar
# String after removing a is: tny rikwr

# %%
# Write a program that can check whether a given string is palindrome or not.
# abba
# malayalam

s = input('enter the string')
flag = True
for i in range(0,len(s)//2):
  if s[i] != s[len(s) - i -1]:
    flag = False
    print('Not a Palindrome')
    break

if flag:
  print('Palindrome')
# Out:
# Palindrome

# %%
# Write a python program to convert a string to title case without using the title()
s = input('enter the string')

L = []
for i in s.split():
  L.append(i[0].upper() + i[1:].lower())

print(" ".join(L))
# Out:
# Hi My Name Is Nitish

# %%
# Write a program that can convert an integer to string.

number = int(input('enter the number'))

digits = '0123456789'
result = ''
while number != 0:
  result = digits[number % 10] + result
  number = number//10

print(result)
print(type(result))
# Out:
# 345
# <class 'str'>
