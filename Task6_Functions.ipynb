# %% [markdown]
# ### **`Problem-1:`** Write a Python function that takes a list and returns a new list with unique elements of the first list.
#
# **Exercise 1:**
#
# Input:
#
# ```bash
# [1,2,3,3,3,3,4,5]
# ```
#
# Output:
#
# ```bash
# [1, 2, 3, 4, 5]
# ```

# %%
def unique_list(lst):
    return list(set(lst))

print(unique_list([1,2,3,3,3,3,4,5]))
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **`Problem-2:`** Write a Python function that accepts a hyphen-separated sequence of words as parameter and returns the words in a hyphen-separated sequence after sorting them alphabetically.
#
# **Example 1:**
#
# Input:
# ```bash
# green-red-yellow-black-white
# ```
#
# Output:
# ```bash
# black-green-red-white-yellow
# ```

# %%
# Write code here
def sort_hyphen_words(s):
    words = s.split('-')        # Step 1
    words.sort()                # Step 2
    return '-'.join(words)      # Step 3

# Example
print(sort_hyphen_words("green-red-yellow-black-white"))
# Out:
# black-green-red-white-yellow

# %% [markdown]
# ### **`Problem 3:`** Write a Python function that accepts a string and calculate the number of upper case letters and lower case letters.
#
# ```
# Sample String : 'CampusX is an Online Mentorship Program fOr EnginEering studentS.'
# Expected Output :
# No. of Upper case characters :  9
# No. of Lower case Characters :  47
# ```

# %%
# Write code here
def count_case(s):
    upper = 0
    lower = 0

    for ch in s:
        if ch.isupper():
            upper += 1
        elif ch.islower():
            lower += 1

    print("No. of Upper case characters :", upper)
    print("No. of Lower case Characters :", lower)


# Example
s = 'CampusX is an Online Mentorship Program fOr EnginEering studentS.'
count_case(s)
# Out:
# No. of Upper case characters : 9
# No. of Lower case Characters : 47

# %% [markdown]
# ### **`Problem 4:`** Write a Python program to print the even numbers from a given list.
# ```
# Sample List : [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Expected Result : [2, 4, 6, 8]
# ```

# %%
# Write code here
def get_even_numbers(lst):
    result = []
    
    for num in lst:
        if num % 2 == 0:
            result.append(num)
    
    return result


# Example
sample_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print(get_even_numbers(sample_list))
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# ### **`Problem 5:`** Write a Python function to check whether a number is perfect or not.
#
# A Perfect number is a number that is half the sum of all of its positive divisors (including itself).
#
# Example :
#
# ```
# The first perfect number is 6, because 1, 2, and 3 are its proper positive divisors, and 1 + 2 + 3 = 6.
# Equivalently, the number 6 is equal to half the sum of all its positive divisors: ( 1 + 2 + 3 + 6 ) / 2 = 6.
#
# The next perfect number is 28 = 1 + 2 + 4 + 7 + 14. This is followed by the perfect numbers 496 and 8128.
# ```

# %%
# Write code here
def is_perfect(n):
    if n <= 1:
        return False
    
    divisors_sum = 0
    
    for i in range(1, n):
        if n % i == 0:
            divisors_sum += i
    
    return divisors_sum == n


# Example
num = int(input("Enter number: "))

if is_perfect(num):
    print("Perfect number")
else:
    print("Not a perfect number")
# Out:
# Perfect number

# %% [markdown]
# ### **`Problem-6:`** Write a Python function to concatenate any no of dictionaries to create a new one.
#
# ```
# Sample Dictionary :
# dic1={1:10, 2:20}
# dic2={3:30, 4:40}
# dic3={5:50,6:60}
# Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
# ```

# %%
# Write code here
def concat_dicts(*dicts):
    result = {}
    
    for d in dicts:
        result.update(d)
    
    return result


# Example
dic1 = {1:10, 2:20}
dic2 = {3:30, 4:40}
dic3 = {5:50, 6:60}

print(concat_dicts(dic1, dic2, dic3))
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %% [markdown]
# `Problem-7` Write a python function that accepts a string as input and returns the word with most occurence.
#
# ```
# Input:
# hello how are you i am fine thank you
# ```
#
# ```
# Output
# you -> 2
# ```

# %%
# Write code here
def max_occurrence_word(s):
    words = s.split()
    freq = {}

    # Count frequency
    for word in words:
        freq[word] = freq.get(word, 0) + 1

    # Find max occurring word
    max_word = max(freq, key=freq.get)
    
    print(f"{max_word} -> {freq[max_word]}")


# Example
s = "hello how are you i am fine thank you"
max_occurrence_word(s)
# Out:
# you -> 2

# %% [markdown]
# `Problem-8` Write a python function that receives a list of integers and prints out a histogram of bin size 10
#
# ```
# Input:
# [13,42,15,37,22,39,41,50]
# ```
#
# ```
# Output:
# {11-20:2,21-30:1,31-40:2,41-50:3}
# ```

# %%
# Write code here
def histogram(lst):
    bins = {}

    for num in lst:
        # Determine bin range
        start = (num // 10) * 10 + 1
        end = start + 9

        key = f"{start}-{end}"

        bins[key] = bins.get(key, 0) + 1

    print(bins)


# Example
lst = [13, 42, 15, 37, 22, 39, 41, 50]
histogram(lst)
# Out:
# {'11-20': 2, '41-50': 2, '31-40': 2, '21-30': 1, '51-60': 1}

# %% [markdown]
# `Problem-9` Write a python function that accepts a list of 2D co-ordinates and a query point, and then finds the the co-ordinate which is closest in terms of distance from the query point.
#
# ```
# List of Coordinates
# [(1,1),(2,2),(3,3),(4,4)]
# Query Point
# (0,0)
# ```
#
# ```
# Output
# Nearest to (0,0) is (1,1)
# ```

# %%
# Write code here
import math

def closest_point(points, query):
    min_dist = float('inf')
    closest = None

    for (x, y) in points:
        dist = math.sqrt((x - query[0])**2 + (y - query[1])**2)
        
        if dist < min_dist:
            min_dist = dist
            closest = (x, y)

    print(f"Nearest to {query} is {closest}")


# Example
points = [(1,1),(2,2),(3,3),(4,4)]
query = (0,0)

closest_point(points, query)
# Out:
# Nearest to (0, 0) is (1, 1)

# %% [markdown]
# ### `Problem-10`:Write a python program that receives a list of strings and performs bag of word operation on those strings
#
# https://en.wikipedia.org/wiki/Bag-of-words_model

# %%
# Write code here
def bag_of_words(sentences):
    bow = {}

    for sentence in sentences:
        words = sentence.lower().split()
        
        for word in words:
            bow[word] = bow.get(word, 0) + 1

    return bow


# Example
texts = [
    "CampusX is best",
    "CampusX is great",
    "best platform for data science"
]

result = bag_of_words(texts)
print(result)
# Out:
# {'campusx': 2, 'is': 2, 'best': 2, 'great': 1, 'platform': 1, 'for': 1, 'data': 1, 'science': 1}

# %% [markdown]
# ### `Problem 11:` Write a Python program to add three given lists using Python map and lambda.

# %%
# Write code here
def add_lists(l1, l2, l3):
    result = list(map(lambda x, y, z: x + y + z, l1, l2, l3))
    return result


# Example
list1 = [1, 2, 3]
list2 = [4, 5, 6]
list3 = [7, 8, 9]

print(add_lists(list1, list2, list3))
# Out:
# [12, 15, 18]

# %% [markdown]
# ### `Problem-12:`Write a Python program to create a list containing the power of said number in bases raised to the corresponding number in the index using Python map.
# `Input:`
# ```
# list1 = [1,2,3,4,5,6]
# ```
# `Output:`
# ```
# [1,2,9,64,625,-]
# ```

# %%
# Write code here
list1 = [1, 2, 3, 4, 5, 6]

result = list(map(lambda x: x[1] ** x[0], enumerate(list1)))

print(result)
# Out:
# [1, 2, 9, 64, 625, 7776]

# %% [markdown]
# ### `Problem-13` Using filter() and list() functions and .lower() method filter all the vowels in a given string.

# %%
# Write code here
def filter_vowels(s):
    vowels = "aeiou"
    
    result = list(filter(lambda ch: ch.lower() in vowels, s))
    
    return result


# Example
s = "CampusX is Awesome"
print(filter_vowels(s))
# Out:
# ['a', 'u', 'i', 'A', 'e', 'o', 'e']

# %% [markdown]
# ### `Problem-14`: Use reduce to convert a 2D list to 1D

# %%
# Write code here
from functools import reduce

def flatten_2d(lst):
    return reduce(lambda x, y: x + y, lst)


# Example
lst = [[1, 2], [3, 4], [5, 6]]

print(flatten_2d(lst))
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### `Problem 15`- A dictionary contains following information about 5 employees:
# - First name
# - Last name
# - Age
# - Grade(Skilled,Semi-skilled,Highly skilled)<br>
# Write a program using map/filter/reduce to a list of employees(first name + last name) who are highly skilled

# %%
# Write code here
employees = [
    {"first_name": "John", "last_name": "Doe", "age": 30, "grade": "Highly skilled"},
    {"first_name": "Jane", "last_name": "Smith", "age": 25, "grade": "Skilled"},
    {"first_name": "Mike", "last_name": "Brown", "age": 35, "grade": "Highly skilled"},
    {"first_name": "Sara", "last_name": "Davis", "age": 28, "grade": "Semi-skilled"},
    {"first_name": "Tom", "last_name": "Wilson", "age": 40, "grade": "Highly skilled"}
]

# Step 1: Filter highly skilled employees
filtered = filter(lambda emp: emp["grade"] == "Highly skilled", employees)

# Step 2: Map to full names
result = list(map(lambda emp: emp["first_name"] + " " + emp["last_name"], filtered))

print(result)
# Out:
# ['John Doe', 'Mike Brown', 'Tom Wilson']

# %%
list(map(lambda x:x['fname'] + ' ' + x['lname'],list(filter(lambda x:True if x['grade'] == 'highly-skilled' else False,employees))))
# Out:
# ['Neha Singh', 'Abhinav Sharma']
